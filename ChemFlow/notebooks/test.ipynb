# %%
path = "/data/hdd1/users/akouk/ChemFlow/ChemFlow/data/interim/props/zinc250k.csv"
import pandas as pd
import numpy as np
#open the file
df = pd.read_csv(path)
df.head()
# Out:
#                                               smiles    plogp       qed  \
# 0          CC(C)(C)c1ccc2occ(CC(=O)Nc3ccccc3F)c2c1\n  5.05060  0.702012
# 1     C[C@@H]1CC(Nc2cncc(-c3nncn3C)c2)C[C@@H](C)C1\n  3.11370  0.928975
# 2  N#Cc1ccc(-c2ccc(O[C@@H](C(=O)N3CCCC3)c3ccccc3)...  4.96778  0.599682
# 3  CCOC(=O)[C@@H]1CCCN(C(=O)c2nc(-c3ccc(C)cc3)n3c...  4.00022  0.690944
# 4  N#CC1=C(SCC(=O)Nc2cccc(Cl)c2)N=C([O-])[C@H](C#...  3.60956  0.789027
#
#         SAS
# 0  2.084095
# 1  3.432004
# 2  2.470633
# 3  2.822753
# 4  4.035182

# %%
#rename logP to plogp
df = df.rename(columns={"SAS": "sa"})
df.head()
# Out:
#                                               smiles    plogp       qed  \
# 0          CC(C)(C)c1ccc2occ(CC(=O)Nc3ccccc3F)c2c1\n  5.05060  0.702012
# 1     C[C@@H]1CC(Nc2cncc(-c3nncn3C)c2)C[C@@H](C)C1\n  3.11370  0.928975
# 2  N#Cc1ccc(-c2ccc(O[C@@H](C(=O)N3CCCC3)c3ccccc3)...  4.96778  0.599682
# 3  CCOC(=O)[C@@H]1CCCN(C(=O)c2nc(-c3ccc(C)cc3)n3c...  4.00022  0.690944
# 4  N#CC1=C(SCC(=O)Nc2cccc(Cl)c2)N=C([O-])[C@H](C#...  3.60956  0.789027
#
#          sa
# 0  2.084095
# 1  3.432004
# 2  2.470633
# 3  2.822753
# 4  4.035182

# %%
#save to the same path
df.to_csv(path, index=False)
